# %%
import numpy as np
import skimage.io
import skimage
import matplotlib.pyplot as plt
import cv2
import numba
from flow2color import *
from tqdm import tqdm

# %%
# I(x,y)
I1, I2 = cv2.imread('yos08.pgm', 0), cv2.imread('yos09.pgm', 0)

# Apply Gaussian Blur
size = 7
#I1, I2 = cv2.GaussianBlur(I1,(size, size),0), cv2.GaussianBlur(I2,(size, size),0)

# Stack the images -- I(x,y,t)
I = np.stack([I1, I2], axis=-1) / 255.0

gt = np.genfromtxt('yos_co.txt')

# Derivatives
Iy, Ix, It = np.gradient(I)

# %%
def flow2image(flow):
    res = np.zeros((flow.shape[0], flow.shape[1], 3), np.uint8)
    for i in range(flow.shape[0]):
        for j in range(flow.shape[1]):
            res[i,j] = np.uint8(flow2color(flow[i,j,0], flow[i,j,1]))
    return res

# %%
def epe(gt, y):
    return np.sqrt((y[:, 0]-gt[:,0])**2 + (y[:, 1]-gt[:,1])**2).mean()
def aae(gt, y):
    return np.rad2deg(np.arccos((y[:, 0] * gt[:, 0] + y[:, 1] * gt[:, 1] + 1) / np.sqrt((y[:, 0]**2 + y[:, 1]**2 + 1) * (gt[:, 0]**2 + gt[:, 1]**2 + 1))).mean())

# %%
@numba.jit(nopython=True)
def sor(Ix, Iy, It, psi1, psi_im1, psi_ip1, psi_jm1, psi_jp1, flow, alpha):
    
    w = 1.95
    ialpha = 1.0 / alpha
    
    # Iterate over u 
    for i in range(flow.shape[0]-1):
        for j in range(flow.shape[1]-1):
            b = - psi1[i,j] * ialpha * It[i,j,0] * Ix[i,j,0]
            # with a minus in the equation
            D = psi1[i,j] * ialpha * Ix[i,j,0] * Ix[i,j,0] + psi_im1[i,j] + psi_ip1[i,j] + psi_jm1[i,j] + psi_jp1[i,j]
            Lx = - psi_im1[i,j] * (flow[i-1,j,0] if i>0 else 0.0) - psi_jm1[i,j] * (flow[i,j-1,0] if j>0 else 0.0)
            Ux = psi1[i,j] * ialpha * Iy[i,j,0] * Ix[i,j,0] * flow[i,j,1] - psi_ip1[i,j] * (flow[i+1,j,0] if i<flow.shape[0]-1 else 0.0) - psi_jp1[i,j] * (flow[i,j+1,0] if j<flow.shape[1]-1 else 0.0)
            
            # with a plus in the equation
            #D = psi1[i,j] * ialpha * Ix[i,j,0] * Ix[i,j,0] - psi_im1[i,j] - psi_ip1[i,j] - psi_jm1[i,j] - psi_jp1[i,j]
            #Lx = psi_im1[i,j] * (flow[i-1,j,0] if i>0 else 0.0) + psi_jm1[i,j] * (flow[i,j-1,0] if j>0 else 0.0)
            #Ux = psi1[i,j] * ialpha * Iy[i,j,0] * Ix[i,j,0] * flow[i,j,1] + psi_ip1[i,j] * (flow[i+1,j,0] if i<flow.shape[0]-1 else 0.0) + psi_jp1[i,j] * (flow[i,j+1,0] if j<flow.shape[1]-1 else 0.0)
            
            flow[i,j,0] = (1-w) * flow[i,j,0] + w * ((b - Lx - Ux) / D)
            
            # with alpha instead of 1/alpha
            #b = - psi1[i,j] * It[i,j,0] * Ix[i,j,0]
            #D = psi1[i,j] * Ix[i,j,0] * Ix[i,j,0] + (psi_im1[i,j] + psi_ip1[i,j] + psi_jm1[i,j] + psi_jp1[i,j]) * alpha
            #Lx = - alpha * psi_im1[i,j] * (flow[i-1,j,0] if i>0 else 0.0) - alpha * psi_jm1[i,j] * (flow[i,j-1,0] if j>0 else 0.0)
            #Ux = psi1[i,j] * Iy[i,j,0] * Ix[i,j,0] * flow[i,j,1] - alpha * psi_ip1[i,j] * (flow[i+1,j,0] if i<flow.shape[0]-1 else 0.0) - alpha * psi_jp1[i,j] * (flow[i,j+1,0] if j<flow.shape[1]-1 else 0.0)
            #flow[i,j,0] = (1-w) * flow[i,j,0] + w * ((b - Lx - Ux) / D)
            
    # Iterate over v
    for i in range(flow.shape[0]-1):
        for j in range(flow.shape[1]-1):
            b = - psi1[i,j] * ialpha * It[i,j,0] * Iy[i,j,0]
            # with a minus in the equation
            D = psi1[i,j] * ialpha * Iy[i,j,0] * Iy[i,j,0] + psi_im1[i,j] + psi_ip1[i,j] + psi_jm1[i,j] + psi_jp1[i,j]
            Lx = - psi_im1[i,j] * (flow[i-1,j,1] if i>0 else 0.0) - psi_jm1[i,j] * (flow[i,j-1,1] if j>0 else 0.0)
            Ux = psi1[i,j] * ialpha * Ix[i,j,0] * Iy[i,j,0] * flow[i,j,0] - psi_ip1[i,j] * (flow[i+1,j,1] if i<flow.shape[0]-1 else 0.0) - psi_jp1[i,j] * (flow[i,j+1,1] if j<flow.shape[1]-1 else 0.0)
            
            # with a plus in the equation
            #D = psi1[i,j] * ialpha * Iy[i,j,0] * Iy[i,j,0] - psi_im1[i,j] - psi_ip1[i,j] - psi_jm1[i,j] - psi_jp1[i,j]
            #Lx = psi_im1[i,j] * (flow[i-1,j,1] if i>0 else 0.0) + psi_jm1[i,j] * (flow[i,j-1,1] if j>0 else 0.0)
            #Ux = psi1[i,j] * ialpha * Ix[i,j,0] * Iy[i,j,0] * flow[i,j,0] + psi_ip1[i,j] * (flow[i+1,j,1] if i<flow.shape[0]-1 else 0.0) + psi_jp1[i,j] * (flow[i,j+1,1] if j<flow.shape[1]-1 else 0.0)
            
            flow[i,j,1] = (1-w) * flow[i,j,1] + w * ((b - Lx -Ux) / D)
            
            #with alpha instead of 1/alpha, it is the same
            #b = - psi1[i,j] * It[i,j,0] * Iy[i,j,0]
            #D = psi1[i,j] * Iy[i,j,0] * Iy[i,j,0] + (psi_im1[i,j] + psi_ip1[i,j] + psi_jm1[i,j] + psi_jp1[i,j])*alpha
            #Lx = - alpha * psi_im1[i,j] * (flow[i-1,j,1] if i>0 else 0.0) - alpha * psi_jm1[i,j] * (flow[i,j-1,1] if j>0 else 0.0)
            #Ux = psi1[i,j] * Ix[i,j,0] * Iy[i,j,0] * flow[i,j,0] - alpha * psi_ip1[i,j] * (flow[i+1,j,1] if i<flow.shape[0]-1 else 0.0) - alpha * psi_jp1[i,j] * (flow[i,j+1,1] if j<flow.shape[1]-1 else 0.0)
            #flow[i,j,1] = (1-w) * flow[i,j,1] + w * ((b - Lx -Ux) / D)
            
    return flow

# %%
# Implements Horn-Schunck with both terms non-quadratic (for discontinuities and occlusions)

def lagged_diffusivity(gt, Ix, Iy, It, alpha, epsilon, err, num_it_sor):
    flow = np.zeros((Ix.shape[0], Ix.shape[1], 2))
    
    for i in range(100000): 
    
        psi1 = 1 / np.sqrt((Ix[:,:,0]*flow[:,:,0] + Iy[:,:,0]*flow[:,:,1] + It[:,:,0])**2 + epsilon**2)

        flow_im1 = np.vstack([flow[1:,:,:],flow[-1:,:,:]])
        flow_ip1 = np.vstack([flow[:1,:,:],flow[:-1,:,:]])
        flow_jm1 = np.hstack([flow[:,1:,:],flow[:,-1:,:]])
        flow_jp1 = np.hstack([flow[:,:1,:],flow[:,:-1,:]])

        # norm of the gradient squared
        ngs = ((flow_ip1 - flow_im1) / 2)**2 + ((flow_jp1 - flow_jm1) / 2)**2

        ngs_im1 = np.vstack([ngs[1:,:,:],ngs[-1:,:,:]])
        ngs_ip1 = np.vstack([ngs[:1,:,:],ngs[:-1,:,:]])
        ngs_jm1 = np.hstack([ngs[:,1:,:],ngs[:,-1:,:]])
        ngs_jp1 = np.hstack([ngs[:,:1,:],ngs[:,:-1,:]])

        psi_im1 = 0.5 * ((1 / np.sqrt(ngs[:,:,0]+ngs[:,:,1]+epsilon**2)) + (1 / np.sqrt(ngs_im1[:,:,0]+ngs_im1[:,:,1]+epsilon**2)))
        psi_ip1 = 0.5 * ((1 / np.sqrt(ngs[:,:,0]+ngs[:,:,1]+epsilon**2)) + (1 / np.sqrt(ngs_ip1[:,:,0]+ngs_ip1[:,:,1]+epsilon**2)))
        psi_jm1 = 0.5 * ((1 / np.sqrt(ngs[:,:,0]+ngs[:,:,1]+epsilon**2)) + (1 / np.sqrt(ngs_jm1[:,:,0]+ngs_jm1[:,:,1]+epsilon**2)))
        psi_jp1 = 0.5 * ((1 / np.sqrt(ngs[:,:,0]+ngs[:,:,1]+epsilon**2)) + (1 / np.sqrt(ngs_jp1[:,:,0]+ngs_jp1[:,:,1]+epsilon**2)))

        
        for j in range(num_it_sor):
            flow = sor(Ix, Iy, It, psi1, psi_im1, psi_ip1, psi_jm1, psi_jp1, flow, alpha)
            
        print(aae(gt, flow.reshape((-1, 2))))
        
        if abs(err -  aae(gt, flow.reshape((-1, 2)))) < 0.0001:
            print('BYE, BYE', aae(gt, flow.reshape((-1, 2))))
            break
    
    return flow

# %%
flow = lagged_diffusivity(gt, Ix, Iy, It, 15.0, 0.001, 10.0, 10)
cv2.imwrite('cuernos_guay.png', cv2.cvtColor(flow2image(flow),cv2.COLOR_RGB2BGR))
# Out:
# 55.21004274447239
# 55.20448022949764
# 55.19953480380405
# 55.195087483176565
# 55.191053277050074
# 55.18737279749905
# 55.18399657344209
# 55.18087690195426
# 55.1779768522782
# 55.175267705139774
# 55.172727549497765
# 55.17034001149746
# 55.16809279307761
# 55.16597581911827
# 55.1302088267485
# 55.130208826532865
# 55.13020882632829
# 55.130208826134194
# 55.13020882595002
# 55.13020882577529
# 55.130208825609515
# 55.13020882545226
# 55.13020882530303
# 55.130208825161446
# 55.130208825027125
# 55.13020882489967
# 55.13020882477875
# 55.130208824664024
# 55.13020882455518
# 55.13020882445192
# 55.130208824353936
# 55.13020882426097
# 55.130208824172776
# 55.130208824089095
# 55.13020882400969
# 55.13020882393437
# 55.13020882386291
# 55.130208823795094
# 55.13020882373077
# 55.130208823669726
# 55.13020882361182
# 55.13020882355688
# 55.130208823504745
# 55.13020882345528
# 55.13020882340836
# 55.13020882336383
# 55.130208823321595
# 55.130208823281514
# 55.1302088232435
# 55.13020882320742
# 55.130208823173184
# 55.13020882314072
# 55.13020882310991
# 55.130208823080665
# 55.130208823052925
# 55.130208823026614
# 55.13020882300165
# 55.130208822977956
# 55.13020882295549
# 55.13020882293417
# 55.130208822913936
# 55.13020882289473
# 55.13020882287654
# 55.130208822859245
# 55.13020882284284
# 55.1302088228273
# 55.13020882281254
# 55.13020882279856
# 55.13020882278527
# 55.13020882277266
# 55.1302088227607
# 55.13020882274937
# 55.13020882273859
# 55.13020882272838
# 55.1302088227187
# 55.13020882270949
# 55.13020882270078
# 55.130208822692495
# 55.13020882268465
# 55.130208822677204
# 55.13020882267014
# 55.13020882266343
# 55.13020882265706
# 55.130208822651035
# 55.13020882264531
# 55.13020882263988
# 55.130208822634714
# 55.130208822629825
# 55.1302088226252
# 55.13020882262079
# 55.13020882261661
# 55.130208822612644
# 55.130208822608886
# 55.13020882260531
# 55.130208822601936
# 55.13020882259872
# 55.13020882259568
# 55.13020882259278
# 55.13020882259004
# 55.13020882258744
# 55.13020882258496
# 55.13020882258263
# 55.13020882258041
# 55.13020882257829
# 55.13020882257629
# 55.13020882257438
# 55.1302088225726
# 55.130208822570886
# 55.13020882256926
# 55.130208822567724
# 55.13020882256626
# 55.13020882256488
# 55.13020882256357
# 55.13020882256231
# 55.13020882256114
# 55.13020882256002
# 55.13020882255896
# 55.13020882255793
# 55.13020882255699
# 55.130208822556064
# 55.130208822555204
# 55.13020882255439
# 55.13020882255361
# 55.13020882255288
# 55.13020882255219
# 55.13020882255151
# 55.13020882255089
# 55.130208822550294
# 55.130208822549726
# 55.13020882254918
# 55.13020882254868
# 55.13020882254819
# 55.130208822547736
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-00ee5c55b1c4> in <module>
# ----> 1 flow = lagged_diffusivity(gt, Ix, Iy, It, 15.0, 0.001, 10.0, 10)
#       2 cv2.imwrite('cuernos_guay.png', cv2.cvtColor(flow2image(flow),cv2.COLOR_RGB2BGR))
#
# <ipython-input-117-76d7320da25c> in lagged_diffusivity(gt, Ix, Iy, It, alpha, epsilon, err, num_it_sor)
#      28
#      29         for j in range(num_it_sor):
# ---> 30             flow = sor(Ix, Iy, It, psi1, psi_im1, psi_ip1, psi_jm1, psi_jp1, flow, alpha)
#      31
#      32         print(aae(gt, flow.reshape((-1, 2))))
#
# KeyboardInterrupt:
